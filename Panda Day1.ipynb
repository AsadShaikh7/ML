# %%
ls=[]
n=int(input("Enter Inputs: "))
for i in range(int(n)):
    dic={}
    dic['Name']=input("Enter Name: ")
    dic['Subject']=input("Enter Subject: ")
    dic['Marks']=input("Enter Marks: ")
    ls.append(dic)
print(ls)
# Out:
# Enter Inputs: 5
# Enter Name: Asad
# Enter Subject: Python
# Enter Marks: 70
# Enter Name: Jigar
# Enter Subject: python
# Enter Marks: 70
# Enter Name: Dhrumit
# Enter Subject: Python
# Enter Marks: 70
# Enter Name: Nikunj
# Enter Subject: Python
# Enter Marks: 70
# Enter Name: Mehak
# Enter Subject: Python
# Enter Marks: 70
# [{'Name': 'Asad', 'Subject': 'Python', 'Marks': '70'}, {'Name': 'Jigar', 'Subject': 'python', 'Marks': '70'}, {'Name': 'Dhrumit', 'Subject': 'Python', 'Marks': '70'}, {'Name': 'Nikunj', 'Subject': 'Python', 'Marks': '70'}, {'Name': 'Mehak', 'Subject': 'Python', 'Marks': '70'}]

# %%
import pandas as pd

# %%
Name = ['Asad','Mehak','Tan','Jigar']
Marks = [70,70,70,70]
df = pd.Series(data=Name)

# %%
print(df)
# Out:
# 0     Asad
# 1    Mehak
# 2      Tan
# 3    Jigar
# dtype: object

# %%
type(df)
# Out:
# pandas.core.series.Series

# %%
student={'Name':Name,'Mark':Marks}
print(student)
type(student)
# Out:
# {'Name': ['Asad', 'Mehak', 'Tan', 'Jigar'], 'Mark': [70, 70, 70, 70]}
# dict

# %%
df = pd.DataFrame(data=student,index=['A','B','C','D'])
df
# Out:
#     Name  Mark
# A   Asad    70
# B  Mehak    70
# C    Tan    70
# D  Jigar    70

# %%
#Rows and Columns
df.shape
# Out:
# (4, 2)

# %%
df.info
# Out:
# <bound method DataFrame.info of     Name  Mark
# A   Asad    70
# B  Mehak    70
# C    Tan    70
# D  Jigar    70>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Name  Mark
# A   Asad    70
# B  Mehak    70
# C    Tan    70
# D  Jigar    70>

# %%
#Top Five Records
df.head()
# Out:
#     Name  Mark
# A   Asad    70
# B  Mehak    70
# C    Tan    70
# D  Jigar    70

# %%
#Top 2 Records
df.head(2)
# Out:
#     Name  Mark
# A   Asad    70
# B  Mehak    70

# %%
#Last 2 Records
df.tail(2)
# Out:
#     Name  Mark
# C    Tan    70
# D  Jigar    70

# %%
df(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8404\572952592.py in <module>
# ----> 1 df(A)
#
# NameError: name 'A' is not defined

# %%
df=pd.read_csv('student.csv')
df
# Out:
#        Name  Age  Marks
# 0      Asad   23     75
# 1     Jigar   22     74
# 2   Dhrumit   21     73
# 3    Nikunj   22     72
# 4     Mehak   24     71
# 5       Tan   23     70
# 6    Pushpa   23     69
# 7     Parth   23     68
# 8      Vraj   23     67
# 9    Mitesh   23     66
# 10   Hardik   23     65
# 11   Alkesh   23     64
# 12      Jay   23     63
# 13    Vivek   23     62
# 14   Sameer   23     61
# 15    Dhruv   23     60
# 16   Mishan   23     59
# 17     Yash   23     58
# 18  Prateek   23     57
# 19   Antima   23     56

# %%
df.shape
# Out:
# (20, 3)

# %%
df.size
# Out:
# 60

# %%
df.head()
# Out:
#       Name  Age  Marks
# 0     Asad   23     75
# 1    Jigar   22     74
# 2  Dhrumit   21     73
# 3   Nikunj   22     72
# 4    Mehak   24     71

# %%
df.tail()
# Out:
#        Name  Age  Marks
# 15    Dhruv   23     60
# 16   Mishan   23     59
# 17     Yash   23     58
# 18  Prateek   23     57
# 19   Antima   23     56

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df.iloc[0])
# Out:
# Name     Asad
# Age        23
# Marks      75
# Name: 0, dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')

# %%
print(df.iloc[:,0])
# Out:
# 0        Asad
# 1       Jigar
# 2     Dhrumit
# 3      Nikunj
# 4       Mehak
# 5         Tan
# 6      Pushpa
# 7       Parth
# 8        Vraj
# 9      Mitesh
# 10     Hardik
# 11     Alkesh
# 12        Jay
# 13      Vivek
# 14     Sameer
# 15      Dhruv
# 16     Mishan
# 17       Yash
# 18    Prateek
# 19     Antima
# Name: Name, dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Name  Age  Marks
# 0      Asad   23     75
# 1     Jigar   22     74
# 2   Dhrumit   21     73
# 3    Nikunj   22     72
# 4     Mehak   24     71
# 5       Tan   23     70
# 6    Pushpa   23     69
# 7     Parth   23     68
# 8      Vraj   23     67
# 9    Mitesh   23     66
# 10   Hardik   23     65
# 11   Alkesh   23     64
# 12      Jay   23     63
# 13    Vivek   23     62
# 14   Sameer   23     61
# 15    Dhruv   23     60
# 16   Mishan   23     59
# 17     Yash   23     58
# 18  Prateek   23     57
# 19   Antima   23     56>

# %%
df.info
# Out:
# <bound method DataFrame.info of     Name  Mark
# A   Asad    70
# B  Mehak    70
# C    Tan    70
# D  Jigar    70>

# %%
df=pd.read_csv('student.csv')
df
# Out:
#        Name  Age  Marks
# 0      Asad   23     75
# 1     Jigar   22     74
# 2   Dhrumit   21     73
# 3    Nikunj   22     72
# 4     Mehak   24     71
# 5       Tan   23     70
# 6    Pushpa   23     69
# 7     Parth   23     68
# 8      Vraj   23     67
# 9    Mitesh   23     66
# 10   Hardik   23     65
# 11   Alkesh   23     64
# 12      Jay   23     63
# 13    Vivek   23     62
# 14   Sameer   23     61
# 15    Dhruv   23     60
# 16   Mishan   23     59
# 17     Yash   23     58
# 18  Prateek   23     57
# 19   Antima   23     56

# %%
df[['Name','Age']]
# Out:
#        Name  Age
# 0      Asad   23
# 1     Jigar   22
# 2   Dhrumit   21
# 3    Nikunj   22
# 4     Mehak   24
# 5       Tan   23
# 6    Pushpa   23
# 7     Parth   23
# 8      Vraj   23
# 9    Mitesh   23
# 10   Hardik   23
# 11   Alkesh   23
# 12      Jay   23
# 13    Vivek   23
# 14   Sameer   23
# 15    Dhruv   23
# 16   Mishan   23
# 17     Yash   23
# 18  Prateek   23
# 19   Antima   23

# %%
df.iloc[12:19]
# Out:
#        Name  Age  Marks
# 12      Jay   23     63
# 13    Vivek   23     62
# 14   Sameer   23     61
# 15    Dhruv   23     60
# 16   Mishan   23     59
# 17     Yash   23     58
# 18  Prateek   23     57

# %%
df.head(3)
# Out:
#       Name  Age  Marks
# 0     Asad   23     75
# 1    Jigar   22     74
# 2  Dhrumit   21     73

# %%
df.tail(3)
# Out:
#        Name  Age  Marks
# 17     Yash   23     58
# 18  Prateek   23     57
# 19   Antima   23     56

# %%
df[['Name','Marks']]
# Out:
#        Name  Marks
# 0      Asad     75
# 1     Jigar     74
# 2   Dhrumit     73
# 3    Nikunj     72
# 4     Mehak     71
# 5       Tan     70
# 6    Pushpa     69
# 7     Parth     68
# 8      Vraj     67
# 9    Mitesh     66
# 10   Hardik     65
# 11   Alkesh     64
# 12      Jay     63
# 13    Vivek     62
# 14   Sameer     61
# 15    Dhruv     60
# 16   Mishan     59
# 17     Yash     58
# 18  Prateek     57
# 19   Antima     56

# %%
df2=df.rename(columns={'Age':'Duration'})
df2
# Out:
#        Name  Duration  Marks
# 0      Asad        23     75
# 1     Jigar        22     74
# 2   Dhrumit        21     73
# 3    Nikunj        22     72
# 4     Mehak        24     71
# 5       Tan        23     70
# 6    Pushpa        23     69
# 7     Parth        23     68
# 8      Vraj        23     67
# 9    Mitesh        23     66
# 10   Hardik        23     65
# 11   Alkesh        23     64
# 12      Jay        23     63
# 13    Vivek        23     62
# 14   Sameer        23     61
# 15    Dhruv        23     60
# 16   Mishan        23     59
# 17     Yash        23     58
# 18  Prateek        23     57
# 19   Antima        23     56
